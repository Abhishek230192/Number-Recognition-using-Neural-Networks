# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
from tensorflow import keras
import seaborn as sns

# %%
(X_train,y_train),(X_test,y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[0])

# %%
X_train = X_train/255

# %%
X_test = X_test/255

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 616us/step - loss: 0.4621 - accuracy: 0.8798
# Epoch 2/5
# 1875/1875 [==============================] - 1s 614us/step - loss: 0.3034 - accuracy: 0.9153
# Epoch 3/5
# 1875/1875 [==============================] - 1s 616us/step - loss: 0.2832 - accuracy: 0.9209
# Epoch 4/5
# 1875/1875 [==============================] - 1s 616us/step - loss: 0.2729 - accuracy: 0.9236
# Epoch 5/5
# 1875/1875 [==============================] - 1s 612us/step - loss: 0.2664 - accuracy: 0.9251

# %%
y_pred = model.predict(X_test)
# Out:
# 313/313 [==============================] - 0s 491us/step

# %%
model.evaluate(X_test,y_test
              )
# Out:
# 313/313 [==============================] - 0s 561us/step - loss: 0.2697 - accuracy: 0.9261
# [0.26970699429512024, 0.9261000156402588]

# %%
y_pred[0]
# Out:
# array([3.6498047e-02, 3.4078508e-07, 7.9403616e-02, 9.4472355e-01,
#        3.3617569e-03, 1.1803189e-01, 2.3879631e-06, 9.9982464e-01,
#        1.1110652e-01, 7.2004759e-01], dtype=float32)

# %%
np.argmax(y_pred[0])
# Out:
# 7

# %%
plt.matshow(X_test[0])

# %%
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(100, activation='relu'),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 837us/step - loss: 0.2718 - accuracy: 0.9220
# Epoch 2/5
# 1875/1875 [==============================] - 2s 824us/step - loss: 0.1234 - accuracy: 0.9639
# Epoch 3/5
# 1875/1875 [==============================] - 2s 821us/step - loss: 0.0881 - accuracy: 0.9734
# Epoch 4/5
# 1875/1875 [==============================] - 2s 826us/step - loss: 0.0673 - accuracy: 0.9797
# Epoch 5/5
# 1875/1875 [==============================] - 2s 827us/step - loss: 0.0530 - accuracy: 0.9836

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 638us/step - loss: 0.0793 - accuracy: 0.9763
# [0.07930325716733932, 0.9763000011444092]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_1 (Dense)             (None, 100)               78500
#
#  dense_2 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(100, activation='relu'),
                          keras.layers.Dense(1000, activation='relu'),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2178 - accuracy: 0.9346
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0953 - accuracy: 0.9701
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0684 - accuracy: 0.9783
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0519 - accuracy: 0.9830
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0405 - accuracy: 0.9865

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 100)               78500
#
#  dense_4 (Dense)             (None, 1000)              101000
#
#  dense_5 (Dense)             (None, 10)                10010
#
# ...
# Total params: 189,510
# Trainable params: 189,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred=model.predict(X_test)
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# 313/313 [==============================] - 0s 653us/step
# <AxesSubplot:>

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 850us/step - loss: 0.0956 - accuracy: 0.9745
# [0.09559366106987, 0.9745000004768372]
