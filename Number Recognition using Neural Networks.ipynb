# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
from tensorflow import keras
import seaborn as sns

# %%
(X_train,y_train),(X_test,y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[0])

# %%
X_train = X_train/255

# %%
X_test = X_test/255

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 662us/step - loss: 0.4730 - accuracy: 0.8760
# Epoch 2/5
# 1875/1875 [==============================] - 1s 653us/step - loss: 0.3034 - accuracy: 0.9153
# Epoch 3/5
# 1875/1875 [==============================] - 1s 659us/step - loss: 0.2833 - accuracy: 0.9211
# Epoch 4/5
# 1875/1875 [==============================] - 1s 650us/step - loss: 0.2728 - accuracy: 0.9241
# Epoch 5/5
# 1875/1875 [==============================] - 1s 661us/step - loss: 0.2663 - accuracy: 0.9266

# %%
y_pred = model.predict(X_test)
# Out:
# 313/313 [==============================] - 0s 516us/step

# %%
model.evaluate(X_test,y_test
              )
# Out:
# 313/313 [==============================] - 0s 596us/step - loss: 0.2678 - accuracy: 0.9267
# [0.2677781879901886, 0.9266999959945679]

# %%
y_pred[0]
# Out:
# array([1.86474305e-02, 3.60120310e-07, 5.34839295e-02, 9.27927434e-01,
#        1.87336956e-03, 1.11999616e-01, 1.45525280e-06, 9.99709666e-01,
#        7.12982714e-02, 6.52703464e-01], dtype=float32)

# %%
np.argmax(y_pred[0])
# Out:
# 7

# %%
plt.matshow(X_test[0])

# %%
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(100, activation='relu'),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 961us/step - loss: 0.2719 - accuracy: 0.9225
# Epoch 2/5
# 1875/1875 [==============================] - 2s 886us/step - loss: 0.1261 - accuracy: 0.9627
# Epoch 3/5
# 1875/1875 [==============================] - 2s 914us/step - loss: 0.0890 - accuracy: 0.9734
# Epoch 4/5
# 1875/1875 [==============================] - 2s 999us/step - loss: 0.0661 - accuracy: 0.9802
# Epoch 5/5
# 1875/1875 [==============================] - 2s 878us/step - loss: 0.0532 - accuracy: 0.9839

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 673us/step - loss: 0.0920 - accuracy: 0.9709
# [0.09201321750879288, 0.9708999991416931]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_1 (Dense)             (None, 100)               78500
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <AxesSubplot:>

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(100, activation='relu'),
                          keras.layers.Dense(1000, activation='relu'),
                          keras.layers.Dense(10, activation='sigmoid')
                                               ])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2179 - accuracy: 0.9333
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0953 - accuracy: 0.9710
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0686 - accuracy: 0.9783
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0513 - accuracy: 0.9835
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0412 - accuracy: 0.9866

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_9 (Dense)             (None, 100)               78500
#
#  dense_10 (Dense)            (None, 1000)              101000
#
#  dense_11 (Dense)            (None, 10)                10010
#
# =================================================================
# Total params: 189,510
# Trainable params: 189,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred=model.predict(X_test)
y_predicated = [np.argmax(i) for i in y_pred]
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicated)
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# 313/313 [==============================] - 0s 734us/step
# <AxesSubplot:>
